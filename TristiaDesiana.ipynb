# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'Tristia Desiana.jpeg'
img = cv2.imread(img_path)
print(img.shape)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (1280, 720, 3)
# [[[115 110 140]
#   [115 110 140]
#   [115 110 140]
#   ...
#   [125 122 151]
#   [126 121 153]
#   [127 122 154]]
#
#  [[115 110 140]
#   [115 110 140]
#   [115 110 140]
#   ...
#   [125 122 151]
#   [127 122 154]
#   [127 122 154]]
#
#  [[115 110 140]
#   [115 110 140]
#   [115 110 140]
#   ...
#   [126 121 151]
#   [128 121 154]
#   [128 121 154]]
#
#  ...
#
#  [[ 16  12  13]
#   [ 16  12  13]
#   [ 15  11  12]
#   ...
#   [ 16  12  13]
#   [ 16  12  13]
#   [ 16  12  13]]
#
#  [[ 16  12  13]
#   [ 16  12  13]
#   [ 15  11  12]
#   ...
#   [ 16  12  13]
#   [ 16  12  13]
#   [ 16  12  13]]
#
#  [[ 16  12  13]
#   [ 15  11  12]
#   [ 15  11  12]
#   ...
#   [ 16  12  13]
#   [ 16  12  13]
#   [ 16  12  13]]]

# %%
fix_img[:] = np.max(fix_img, axis=-1, keepdims=1)/2 + np.min(fix_img, axis=-1, keepdims=1)/2
print(np.array(fix_img[:]))

plt.axis('off')
plt.imshow(fix_img[:])
plt.savefig('Lightness', bbox_inches= 'tight')
# Out:
# [[[125 125 125]
#   [125 125 125]
#   [125 125 125]
#   ...
#   [136 136 136]
#   [137 137 137]
#   [138 138 138]]
#
#  [[125 125 125]
#   [125 125 125]
#   [125 125 125]
#   ...
#   [136 136 136]
#   [138 138 138]
#   [138 138 138]]
#
#  [[125 125 125]
#   [125 125 125]
#   [125 125 125]
#   ...
#   [136 136 136]
#   [137 137 137]
#   [137 137 137]]
#
#  ...
#
#  [[ 14  14  14]
#   [ 14  14  14]
#   [ 13  13  13]
#   ...
#   [ 14  14  14]
#   [ 14  14  14]
#   [ 14  14  14]]
#
#  [[ 14  14  14]
#   [ 14  14  14]
#   [ 13  13  13]
#   ...
#   [ 14  14  14]
#   [ 14  14  14]
#   [ 14  14  14]]
#
#  [[ 14  14  14]
#   [ 13  13  13]
#   [ 13  13  13]
#   ...
#   [ 14  14  14]
#   [ 14  14  14]
#   [ 14  14  14]]]

# %%
gray_img = np.mean(fix_img, axis=-1)
print(np.array(gray_img))

plt.axis('off')
plt.imshow(gray_img)
plt.savefig('Average', bbox_inches= 'tight')
# Out:
# [[121.66666667 121.66666667 121.66666667 ... 132.66666667 133.33333333
#   134.33333333]
#  [121.66666667 121.66666667 121.66666667 ... 132.66666667 134.33333333
#   134.33333333]
#  [121.66666667 121.66666667 121.66666667 ... 132.66666667 134.33333333
#   134.33333333]
#  ...
#  [ 13.66666667  13.66666667  12.66666667 ...  13.66666667  13.66666667
#    13.66666667]
#  [ 13.66666667  13.66666667  12.66666667 ...  13.66666667  13.66666667
#    13.66666667]
#  [ 13.66666667  12.66666667  12.66666667 ...  13.66666667  13.66666667
#    13.66666667]]

# %%
wav_img = (0.299*R) + (0.587*G) + (0.114*B)
print(np.array(wav_img))

plt.axis('off')
plt.imshow(wav_img, cmap='gray')
plt.savefig('Weighted Average', bbox_inches= 'tight')
# Out:
# [[114.915 114.915 114.915 ... 126.203 126.143 127.143]
#  [114.915 114.915 114.915 ... 126.203 127.143 127.143]
#  [114.915 114.915 114.915 ... 125.915 126.855 126.855]
#  ...
#  [ 13.31   13.31   12.31  ...  13.31   13.31   13.31 ]
#  [ 13.31   13.31   12.31  ...  13.31   13.31   13.31 ]
#  [ 13.31   12.31   12.31  ...  13.31   13.31   13.31 ]]

# %%
lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(np.array(lumi_img))

plt.axis('off')
plt.imshow(lumi_img, cmap='gray')
plt.savefig('Luminosity', bbox_inches= 'tight')
# Out:
# [[113.229  113.229  113.229  ... 124.7316 124.3734 125.3734]
#  [113.229  113.229  113.229  ... 124.7316 125.3734 125.3734]
#  [113.229  113.229  113.229  ... 124.229  124.8708 124.8708]
#  ...
#  [ 12.9226  12.9226  11.9226 ...  12.9226  12.9226  12.9226]
#  [ 12.9226  12.9226  11.9226 ...  12.9226  12.9226  12.9226]
#  [ 12.9226  11.9226  11.9226 ...  12.9226  12.9226  12.9226]]
